# %% [markdown]
# # MS-PlateNet OCR Notebook
#
# Cell-by-cell workflow: Fast Plate OCR, EasyOCR, RapidOCR, PaddleOCR, then combined comparison table.
#
# GPU is used automatically where available (EasyOCR, RapidOCR, PaddleOCR, and the YOLO detector all auto-detect CUDA and fall back to CPU if no GPU is found).

# %%
# RapidOCR (ONNXRuntime-based -- works on CPU out of the box; for GPU it
# uses onnxruntime-gpu if installed, otherwise silently uses CPU).
# !pip install rapidocr onnxruntime --break-system-packages

# Uncomment the line below INSTEAD of onnxruntime above if you have a
# CUDA-capable GPU + matching CUDA/cuDNN installed, to let RapidOCR run on GPU:
# !pip install rapidocr onnxruntime-gpu --break-system-packages
# Out:
# Requirement already satisfied: rapidocr in c:\software\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: onnxruntime in c:\software\anaconda3\lib\site-packages (1.24.4)
# Requirement already satisfied: pyclipper>=1.2.0 in c:\software\anaconda3\lib\site-packages (from rapidocr) (1.4.0)
# Requirement already satisfied: opencv_python>=4.5.1.48 in c:\software\anaconda3\lib\site-packages (from rapidocr) (4.12.0.88)
# Requirement already satisfied: numpy<3.0.0,>=1.19.5 in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.2.6)
# Requirement already satisfied: six>=1.15.0 in c:\software\anaconda3\lib\site-packages (from rapidocr) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.1.2)
# Requirement already satisfied: PyYAML in c:\software\anaconda3\lib\site-packages (from rapidocr) (6.0.2)
# Requirement already satisfied: Pillow in c:\software\anaconda3\lib\site-packages (from rapidocr) (12.0.0)
# Requirement already satisfied: tqdm in c:\software\anaconda3\lib\site-packages (from rapidocr) (4.66.4)
# Requirement already satisfied: omegaconf!=2.2.1 in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.3.0)
# Requirement already satisfied: requests in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.32.5)
# Requirement already satisfied: colorlog in c:\software\anaconda3\lib\site-packages (from rapidocr) (6.10.1)
# Requirement already satisfied: flatbuffers in c:\software\anaconda3\lib\site-packages (from onnxruntime) (24.12.23)
# Requirement already satisfied: packaging in c:\software\anaconda3\lib\site-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in c:\software\anaconda3\lib\site-packages (from onnxruntime) (3.20.2)
# Requirement already satisfied: sympy in c:\software\anaconda3\lib\site-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\software\anaconda3\lib\site-packages (from omegaconf!=2.2.1->rapidocr) (4.9.3)
# Requirement already satisfied: colorama in c:\software\anaconda3\lib\site-packages (from colorlog->rapidocr) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (2023.7.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\software\anaconda3\lib\site-packages (from sympy->onnxruntime) (1.3.0)
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: rapidocr in c:\software\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: onnxruntime-gpu in c:\software\anaconda3\lib\site-packages (1.23.2)
# Requirement already satisfied: pyclipper>=1.2.0 in c:\software\anaconda3\lib\site-packages (from rapidocr) (1.4.0)
# Requirement already satisfied: opencv_python>=4.5.1.48 in c:\software\anaconda3\lib\site-packages (from rapidocr) (4.12.0.88)
# Requirement already satisfied: numpy<3.0.0,>=1.19.5 in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.2.6)
# Requirement already satisfied: six>=1.15.0 in c:\software\anaconda3\lib\site-packages (from rapidocr) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.1.2)
# Requirement already satisfied: PyYAML in c:\software\anaconda3\lib\site-packages (from rapidocr) (6.0.2)
# Requirement already satisfied: Pillow in c:\software\anaconda3\lib\site-packages (from rapidocr) (12.0.0)
# Requirement already satisfied: tqdm in c:\software\anaconda3\lib\site-packages (from rapidocr) (4.66.4)
# Requirement already satisfied: omegaconf!=2.2.1 in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.3.0)
# Requirement already satisfied: requests in c:\software\anaconda3\lib\site-packages (from rapidocr) (2.32.5)
# Requirement already satisfied: colorlog in c:\software\anaconda3\lib\site-packages (from rapidocr) (6.10.1)
# Requirement already satisfied: coloredlogs in c:\software\anaconda3\lib\site-packages (from onnxruntime-gpu) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\software\anaconda3\lib\site-packages (from onnxruntime-gpu) (24.12.23)
# Requirement already satisfied: packaging in c:\software\anaconda3\lib\site-packages (from onnxruntime-gpu) (25.0)
# Requirement already satisfied: protobuf in c:\software\anaconda3\lib\site-packages (from onnxruntime-gpu) (3.20.2)
# Requirement already satisfied: sympy in c:\software\anaconda3\lib\site-packages (from onnxruntime-gpu) (1.13.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\software\anaconda3\lib\site-packages (from omegaconf!=2.2.1->rapidocr) (4.9.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\software\anaconda3\lib\site-packages (from coloredlogs->onnxruntime-gpu) (10.0)
# Requirement already satisfied: colorama in c:\software\anaconda3\lib\site-packages (from colorlog->rapidocr) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\software\anaconda3\lib\site-packages (from requests->rapidocr) (2023.7.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\software\anaconda3\lib\site-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\software\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime-gpu) (3.5.4)
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'

# %%
# PaddleOCR + PaddlePaddle.
#
# IMPORTANT: paddlepaddle==3.3.0 has a confirmed bug that breaks CPU
# inference for every PaddleOCR pipeline model with:
#   NotImplementedError: (Unimplemented) ConvertPirAttribute2RuntimeAttribute ...
# (see https://github.com/PaddlePaddle/Paddle/issues/77340). We pin 3.2.2
# below, which is the version before the regression and is confirmed working.
# If a newer 3.3.x patch release fixes this in the future, you can drop the
# version pin.
# !pip install paddleocr --break-system-packages
# !pip install "paddlepaddle==3.2.2" --break-system-packages

# GPU build alternative (pick the command matching your installed CUDA version,
# see https://www.paddlepaddle.org.cn/en/install/quick for the right index URL):
# !pip install "paddlepaddle-gpu==3.2.2" --break-system-packages
# Out:
# Requirement already satisfied: paddleocr in c:\software\anaconda3\lib\site-packages (3.4.0)
# Requirement already satisfied: paddlex<3.5.0,>=3.4.0 in c:\software\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (3.4.3)
# Requirement already satisfied: PyYAML>=6 in c:\software\anaconda3\lib\site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: requests in c:\software\anaconda3\lib\site-packages (from paddleocr) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.12 in c:\software\anaconda3\lib\site-packages (from paddleocr) (4.15.0)
# Requirement already satisfied: aistudio-sdk>=0.3.5 in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.3.8)
# Requirement already satisfied: chardet in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (4.0.0)
# Requirement already satisfied: colorlog in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (6.10.1)
# Requirement already satisfied: filelock in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (3.20.0)
# Requirement already satisfied: huggingface-hub in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.27.1)
# Requirement already satisfied: modelscope>=1.28.0 in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (1.35.3)
# Requirement already satisfied: numpy>=1.24 in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2.2.6)
# Requirement already satisfied: packaging in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (25.0)
# Requirement already satisfied: pandas>=1.3 in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2.2.3)
# Requirement already satisfied: pillow in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (12.0.0)
# Requirement already satisfied: prettytable in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (3.17.0)
# Requirement already satisfied: py-cpuinfo in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (9.0.0)
# Requirement already satisfied: pydantic>=2 in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2.10.5)
# Requirement already satisfied: ruamel.yaml in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.17.21)
# Requirement already satisfied: ujson in c:\software\anaconda3\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (5.10.0)
# Requirement already satisfied: imagesize in c:\software\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (1.4.1)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in c:\software\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (4.10.0.84)
# Requirement already satisfied: pyclipper in c:\software\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (1.4.0)
# Requirement already satisfied: pypdfium2>=4 in c:\software\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (5.6.0)
# Requirement already satisfied: python-bidi in c:\software\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.6.7)
# Requirement already satisfied: shapely in c:\software\anaconda3\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\software\anaconda3\lib\site-packages (from requests->paddleocr) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\software\anaconda3\lib\site-packages (from requests->paddleocr) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\software\anaconda3\lib\site-packages (from requests->paddleocr) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\software\anaconda3\lib\site-packages (from requests->paddleocr) (2023.7.22)
# Requirement already satisfied: psutil in c:\software\anaconda3\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (7.1.3)
# Requirement already satisfied: tqdm in c:\software\anaconda3\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (4.66.4)
# Requirement already satisfied: bce-python-sdk in c:\software\anaconda3\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.9.68)
# Requirement already satisfied: click in c:\software\anaconda3\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (8.1.7)
# Requirement already satisfied: setuptools in c:\software\anaconda3\lib\site-packages (from modelscope>=1.28.0->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (80.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\software\anaconda3\lib\site-packages (from pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\software\anaconda3\lib\site-packages (from pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\software\anaconda3\lib\site-packages (from pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\software\anaconda3\lib\site-packages (from pydantic>=2->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\software\anaconda3\lib\site-packages (from pydantic>=2->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2.27.2)
# Requirement already satisfied: colorama in c:\software\anaconda3\lib\site-packages (from colorlog->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.4.6)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\software\anaconda3\lib\site-packages (from huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2025.12.0)
# Requirement already satisfied: wcwidth in c:\software\anaconda3\lib\site-packages (from prettytable->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\software\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (1.17.0)
# Requirement already satisfied: pycryptodome>=3.8.0 in c:\software\anaconda3\lib\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (3.23.0)
# Requirement already satisfied: future>=0.6.0 in c:\software\anaconda3\lib\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (1.0.0)
# Requirement already satisfied: crc32c>=2.2.post0 in c:\software\anaconda3\lib\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr) (2.8)
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: paddlepaddle==3.2.2 in c:\software\anaconda3\lib\site-packages (3.2.2)
# Requirement already satisfied: httpx in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (0.27.0)
# Requirement already satisfied: numpy>=1.21 in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (2.2.6)
# Requirement already satisfied: protobuf>=3.20.2 in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (3.20.2)
# Requirement already satisfied: Pillow in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (12.0.0)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (3.3.0)
# Requirement already satisfied: networkx in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (3.6.1)
# Requirement already satisfied: typing-extensions in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (4.15.0)
# Requirement already satisfied: safetensors>=0.6.0 in c:\software\anaconda3\lib\site-packages (from paddlepaddle==3.2.2) (0.8.0)
# Requirement already satisfied: anyio in c:\software\anaconda3\lib\site-packages (from httpx->paddlepaddle==3.2.2) (4.2.0)
# Requirement already satisfied: certifi in c:\software\anaconda3\lib\site-packages (from httpx->paddlepaddle==3.2.2) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\software\anaconda3\lib\site-packages (from httpx->paddlepaddle==3.2.2) (1.0.2)
# Requirement already satisfied: idna in c:\software\anaconda3\lib\site-packages (from httpx->paddlepaddle==3.2.2) (2.10)
# Requirement already satisfied: sniffio in c:\software\anaconda3\lib\site-packages (from httpx->paddlepaddle==3.2.2) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\software\anaconda3\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle==3.2.2) (0.14.0)
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\sympy-1.14.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Software\anaconda3\Lib\site-packages\pyyaml-6.0.3.dist-info due to invalid metadata entry 'name'

# %%
import cv2, re, time
import numpy as np
import pandas as pd
from pathlib import Path
from difflib import SequenceMatcher

# %%
# --- GPU detection (shared by every OCR engine below) ---------------------
# We try to ask torch (if installed) whether CUDA is available. If torch
# isn't installed, or it says no, we treat the machine as CPU-only. Each
# engine below still wraps its own GPU init in a try/except and falls back
# to CPU on its own if GPU init fails for an engine-specific reason (e.g.
# wrong onnxruntime-gpu/CUDA version, paddle CPU-only build, etc.) -- this
# flag is just an optimistic first guess, not a hard guarantee.
GPU_AVAILABLE = False
try:
    import torch
    GPU_AVAILABLE = torch.cuda.is_available()
except Exception:
    GPU_AVAILABLE = False

print(f'[gpu] GPU_AVAILABLE = {GPU_AVAILABLE}')

try:
    from ultralytics import YOLO
except Exception as e:
    YOLO = None
    print(f'[import] ultralytics unavailable: {type(e).__name__}: {e}')

# FIX: class is named LicensePlateRecognizer in current fast-plate-ocr releases
# (ONNXPlateRecognizer was the old name and no longer exists).
try:
    from fast_plate_ocr import LicensePlateRecognizer
except Exception as e:
    LicensePlateRecognizer = None
    print(f'[import] fast_plate_ocr unavailable: {type(e).__name__}: {e}')

try:
    import easyocr
except Exception as e:
    easyocr = None
    print(f'[import] easyocr unavailable: {type(e).__name__}: {e}')

try:
    from rapidocr import RapidOCR
except Exception as e:
    try:
        # older package name: rapidocr_onnxruntime
        from rapidocr_onnxruntime import RapidOCR
    except Exception as e2:
        RapidOCR = None
        print(f'[import] rapidocr unavailable: {type(e).__name__}: {e}')

try:
    from paddleocr import PaddleOCR
except Exception as e:
    PaddleOCR = None
    print(f'[import] paddleocr unavailable: {type(e).__name__}: {e}')
# Out:
# [gpu] GPU_AVAILABLE = True
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.

# %%
BASE = Path.cwd()
IMG_DIR = BASE / 'ocr_test_images'
GT_CSV = BASE / 'ground_truth.csv'
OUT_DIR = BASE / 'output'
OUT_DIR.mkdir(exist_ok=True)
MODEL_PATH = Path("Version-5-runs/plateNetV5medium/weights/bestMediumV5.pt")

gt = pd.read_csv(GT_CSV)
img_paths = sorted([p for p in IMG_DIR.glob('*') if p.suffix.lower() in ['.jpg','.jpeg','.png','.bmp']])[:100]

def clean(s):
    return re.sub(r'[^A-Z0-9]', '', str(s).upper()) if s is not None else ''

def sim(a, b):
    return SequenceMatcher(None, clean(a), clean(b)).ratio()

# %%
if YOLO is None:
    raise ImportError('ultralytics is not installed')
if not MODEL_PATH.exists():
    raise FileNotFoundError(f'Model not found: {MODEL_PATH}')

model = YOLO(str(MODEL_PATH))

# FIX: device=0 hardcoded GPU index 0 and would crash with no CUDA device
# present. Use the shared GPU_AVAILABLE flag (computed in the imports cell)
# to run on GPU when one is available and fall back to CPU otherwise.
YOLO_DEVICE = 0 if GPU_AVAILABLE else 'cpu'
print(f'[yolo] running detector on device={YOLO_DEVICE!r}')

def detect_plate_crop(img_bgr):
    results = model.predict(img_bgr, conf=0.25, verbose=False, device=YOLO_DEVICE)
    if not results or len(results) == 0:
        return None, None
    r = results[0]
    if r.boxes is None or len(r.boxes) == 0:
        return None, None
    boxes = r.boxes.xyxy.cpu().numpy()
    confs = r.boxes.conf.cpu().numpy()
    i = int(np.argmax(confs))
    x1, y1, x2, y2 = boxes[i].astype(int)
    h, w = img_bgr.shape[:2]
    x1, y1 = max(0, x1), max(0, y1)
    x2, y2 = min(w, x2), min(h, y2)
    if x2 <= x1 or y2 <= y1:
        return None, None
    return img_bgr[y1:y2, x1:x2].copy(), float(confs[i])
# Out:
# [yolo] running detector on device=0

# %% [markdown]
# ## First cell: Fast Plate OCR

# %%
# FIX: no .predict() method exists on LicensePlateRecognizer -- use .run_one()
# for a single image. It returns a PlatePrediction object/dict with a `.plate`
# field, not the text/result/prediction keys the old code was guessing at.
# FIX: must pass a hub model name (or onnx_model_path); calling with no args
# does not just "use a default" the way the old code assumed.

fast_model = None
if LicensePlateRecognizer is not None:
    try:
        # Pick the hub model matching your plates. Options include:
        # 'cct-xs-v1-global-model', 'cct-s-v2-global-model',
        # 'european-plates-mobile-vit-v2-model', 'global-plates-mobile-vit-v2-model', etc.
        fast_model = LicensePlateRecognizer('cct-xs-v1-global-model')
    except Exception as e:
        print(f'[fast_plate_ocr init failed] {type(e).__name__}: {e}')
        fast_model = None
else:
    print('[fast_plate_ocr] not available -- see import error above')

fast_rows = []
for p in img_paths:
    truth_row = gt.loc[gt['image'] == p.name, 'plate']
    truth = clean(truth_row.iloc[0]) if len(truth_row) else ''
    img_bgr = cv2.imread(str(p))
    crop, det_conf = detect_plate_crop(img_bgr)

    pred = ''
    fast_raw = ''
    if fast_model is not None and crop is not None:
        try:
            out = fast_model.run_one(crop)
            fast_raw = str(out)
            plate_text = getattr(out, 'plate', None)
            if plate_text is None and isinstance(out, dict):
                plate_text = out.get('plate')
            pred = clean(plate_text) if plate_text is not None else ''
        except Exception as e:
            fast_raw = f'ERR: {type(e).__name__}: {e}'
            pred = ''
    elif fast_model is None:
        fast_raw = 'ERR: fast_model not initialized'
    elif crop is None:
        fast_raw = 'ERR: no plate detected by YOLO'

    fast_rows.append({
        'image': p.name,
        'truth': truth,
        'fast_raw': fast_raw,
        'fast_plate_ocr': pred,
        'fast_ok': int(pred == truth),
        'fast_sim': round(sim(pred, truth), 4),
        'det_conf': det_conf
    })

fast_df = pd.DataFrame(fast_rows)
fast_df.to_csv(OUT_DIR / 'fast_plate_ocr_results.csv', index=False)
fast_df
# Out:
#          image     truth                                           fast_raw  \
# 0     img1.jpg   MCY6055  PlatePrediction(plate='MCY6055', char_probs=No...
# 1    img10.jpg  SJS4878P  PlatePrediction(plate='SJS4878P', char_probs=N...
# 2   img100.jpg   BHR6449  PlatePrediction(plate='BHR6449', char_probs=No...
# 3    img11.jpg    SMR54X  PlatePrediction(plate='SMR54X', char_probs=Non...
# 4    img12.jpg   WJJ2495  PlatePrediction(plate='WJJ2495', char_probs=No...
# ..         ...       ...                                                ...
# 95   img95.jpg   VCH3295  PlatePrediction(plate='VCH3295', char_probs=No...
# 96   img96.jpg    PQQ922  PlatePrediction(plate='PQQ922', char_probs=Non...
# 97   img97.jpg   PQU6175  PlatePrediction(plate='PQU6175', char_probs=No...
# 98   img98.jpg   WEE6996  PlatePrediction(plate='WEE6996', char_probs=No...
# 99   img99.jpg    KFW698  PlatePrediction(plate='KFW698', char_probs=Non...
#
#    fast_plate_ocr  fast_ok  fast_sim  det_conf
# 0         MCY6055        1       1.0  0.819638
# 1        SJS4878P        1       1.0  0.731283
# 2         BHR6449        1       1.0  0.769302
# 3          SMR54X        1       1.0  0.783089
# 4         WJJ2495        1       1.0  0.861307
# ..            ...      ...       ...       ...
# 95        VCH3295        1       1.0  0.889710
# 96         PQQ922        1       1.0  0.770766
# 97        PQU6175        1       1.0  0.841102
# 98        WEE6996        1       1.0  0.859380
# 99         KFW698        1       1.0  0.837886
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Second cell: EasyOCR

# %%
easy = None
if easyocr is not None:
    try:
        easy = easyocr.Reader(['en'], gpu=GPU_AVAILABLE)
    except Exception as e:
        print(f'[easyocr GPU init failed, retrying on CPU] {type(e).__name__}: {e}')
        try:
            easy = easyocr.Reader(['en'], gpu=False)
        except Exception as e2:
            print(f'[easyocr CPU init also failed] {type(e2).__name__}: {e2}')
            easy = None
else:
    print('[easyocr] not available -- see import error above')

easy_rows = []
for p in img_paths:
    truth_row = gt.loc[gt['image'] == p.name, 'plate']
    truth = clean(truth_row.iloc[0]) if len(truth_row) else ''
    img_bgr = cv2.imread(str(p))
    crop, det_conf = detect_plate_crop(img_bgr)

    pred = ''
    easy_raw = ''
    if easy is not None and crop is not None:
        try:
            texts = easy.readtext(crop, detail=0, paragraph=False)
            easy_raw = str(texts)
            # NOTE: readtext() returning [] (no text detected) is a legitimate
            # "no result" -- ''.join([]) silently becomes '', which previously
            # looked identical to a crash. easy_raw above lets you tell the
            # difference: '[]' means EasyOCR ran but found nothing.
            pred = clean(''.join(texts))
        except Exception as e:
            easy_raw = f'ERR: {type(e).__name__}: {e}'
            pred = ''
    elif easy is None:
        easy_raw = 'ERR: easyocr reader not initialized'
    elif crop is None:
        easy_raw = 'ERR: no plate detected by YOLO'

    easy_rows.append({
        'image': p.name,
        'truth': truth,
        'easy_raw': easy_raw,
        'easyocr': pred,
        'easy_ok': int(pred == truth),
        'easy_sim': round(sim(pred, truth), 4),
        'det_conf': det_conf
    })

easy_df = pd.DataFrame(easy_rows)
easy_df.to_csv(OUT_DIR / 'easyocr_results.csv', index=False)
easy_df
# Out:
#          image     truth         easy_raw   easyocr  easy_ok  easy_sim  \
# 0     img1.jpg   MCY6055     ['McY 6055']   MCY6055        1    1.0000
# 1    img10.jpg  SJS4878P     ['SJS4878P']  SJS4878P        1    1.0000
# 2   img100.jpg   BHR6449     ['BHR 6449']   BHR6449        1    1.0000
# 3    img11.jpg    SMR54X       ['SMREAX']    SMREAX        0    0.6667
# 4    img12.jpg   WJJ2495  ['WJJ', '2495']   WJJ2495        1    1.0000
# ..         ...       ...              ...       ...      ...       ...
# 95   img95.jpg   VCH3295  ['VCH', '3295']   VCH3295        1    1.0000
# 96   img96.jpg    PQQ922      ['PQQ 922']    PQQ922        1    1.0000
# 97   img97.jpg   PQU6175     ['POU 6175']   POU6175        0    0.8571
# 98   img98.jpg   WEE6996      ['WEE6996']   WEE6996        1    1.0000
# 99   img99.jpg    KFW698       ['KFW69B']    KFW69B        0    0.8333
#
#     det_conf
# 0   0.819638
# 1   0.731283
# 2   0.769302
# 3   0.783089
# 4   0.861307
# ..       ...
# 95  0.889710
# 96  0.770766
# 97  0.841102
# 98  0.859380
# 99  0.837886
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Third cell: RapidOCR

# %%
# RapidOCR auto-detects GPU through onnxruntime: if onnxruntime-gpu is
# installed (and a working CUDA/cuDNN setup is found), it uses GPU; otherwise
# it transparently falls back to the CPU onnxruntime build. We just try GPU
# params first and fall back to default (CPU) params if that fails.

rapid_engine = None
if RapidOCR is not None:
    try:
        if GPU_AVAILABLE:
            rapid_engine = RapidOCR(params={"EngineConfig.onnxruntime.use_cuda": True})
        else:
            rapid_engine = RapidOCR()
    except Exception as e:
        print(f'[rapidocr GPU init failed, retrying on CPU] {type(e).__name__}: {e}')
        try:
            rapid_engine = RapidOCR()
        except Exception as e2:
            print(f'[rapidocr CPU init also failed] {type(e2).__name__}: {e2}')
            rapid_engine = None
else:
    print('[rapidocr] not available -- see import error above')

rapid_rows = []
for p in img_paths:
    truth_row = gt.loc[gt['image'] == p.name, 'plate']
    truth = clean(truth_row.iloc[0]) if len(truth_row) else ''
    img_bgr = cv2.imread(str(p))
    crop, det_conf = detect_plate_crop(img_bgr)

    pred = ''
    rapid_raw = ''
    if rapid_engine is not None and crop is not None:
        try:
            result = rapid_engine(crop)
            # RapidOCR returns a result object; .txts holds the recognized
            # strings (newer API) -- fall back to indexing [0] (older API:
            # list of [box, text, score]) if .txts isn't present.
            texts = getattr(result, 'txts', None)
            if texts is None and result:
                texts = [line[1] for line in result[0]] if result[0] else []
            texts = texts or []
            rapid_raw = str(texts)
            pred = clean(''.join(texts))
        except Exception as e:
            rapid_raw = f'ERR: {type(e).__name__}: {e}'
            pred = ''
    elif rapid_engine is None:
        rapid_raw = 'ERR: rapidocr engine not initialized'
    elif crop is None:
        rapid_raw = 'ERR: no plate detected by YOLO'

    rapid_rows.append({
        'image': p.name,
        'truth': truth,
        'rapid_raw': rapid_raw,
        'rapidocr': pred,
        'rapid_ok': int(pred == truth),
        'rapid_sim': round(sim(pred, truth), 4),
        'det_conf': det_conf
    })

rapid_df = pd.DataFrame(rapid_rows)
rapid_df.to_csv(OUT_DIR / 'rapidocr_results.csv', index=False)
rapid_df
# Out:
# [INFO] 2026-07-27 23:54:05,382 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-07-27 23:54:05,388 [RapidOCR] download_file.py:60: File exists and is valid: C:\Software\anaconda3\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-07-27 23:54:05,388 [RapidOCR] main.py:65: Using C:\Software\anaconda3\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [WARNING] 2026-07-27 23:54:05,389 [RapidOCR] provider_config.py:103: CUDAExecutionProvider is not in available providers (['AzureExecutionProvider', 'CPUExecutionProvider']). Use AzureExecutionProvider inference by default.
# [INFO] 2026-07-27 23:54:05,390 [RapidOCR] provider_config.py:203: If you want to use CUDAExecutionProvider acceleration, you must do:(For reference only) If you want to use GPU acceleration, you must do:
# [INFO] 2026-07-27 23:54:05,390 [RapidOCR] provider_config.py:203: First, uninstall all onnxruntime packages in current environment.
# [INFO] 2026-07-27 23:54:05,390 [RapidOCR] provider_config.py:203: Second, install onnxruntime-gpu by `pip install onnxruntime-gpu`.
# [INFO] 2026-07-27 23:54:05,391 [RapidOCR] provider_config.py:203: Note the onnxruntime-gpu version must match your cuda and cudnn version.
# [INFO] 2026-07-27 23:54:05,391 [RapidOCR] provider_config.py:203: You can refer this link: https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html
# [INFO] 2026-07-27 23:54:05,391 [RapidOCR] provider_config.py:203: Third, ensure CUDAExecutionProvider is in available providers list. e.g. ['CUDAExecutionProvider', 'CPUExecutionProvider']
# [WARNING] 2026-07-27 23:54:05,536 [RapidOCR] provider_config.py:103: CUDAExecutionProvider is not in available providers (['AzureExecutionProvider', 'CPUExecutionProvider']). Use AzureExecutionProvider inference by default.
# [INFO] 2026-07-27 23:54:05,537 [RapidOCR] provider_config.py:203: If you want to use CUDAExecutionProvider acceleration, you must do:(For reference only) If you want to use GPU acceleration, you must do:
# [INFO] 2026-07-27 23:54:05,538 [RapidOCR] provider_config.py:203: First, uninstall all onnxruntime packages in current environment.
# [INFO] 2026-07-27 23:54:05,538 [RapidOCR] provider_config.py:203: Second, install onnxruntime-gpu by `pip install onnxruntime-gpu`.
# [INFO] 2026-07-27 23:54:05,538 [RapidOCR] provider_config.py:203: Note the onnxruntime-gpu version must match your cuda and cudnn version.
# [INFO] 2026-07-27 23:54:05,540 [RapidOCR] provider_config.py:203: You can refer this link: https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html
# [INFO] 2026-07-27 23:54:05,540 [RapidOCR] provider_config.py:203: Third, ensure CUDAExecutionProvider is in available providers list. e.g. ['CUDAExecutionProvider', 'CPUExecutionProvider']
# [INFO] 2026-07-27 23:54:05,541 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-07-27 23:54:05,544 [RapidOCR] download_file.py:60: File exists and is valid: C:\Software\anaconda3\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-07-27 23:54:05,544 [RapidOCR] main.py:65: Using C:\Software\anaconda3\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [WARNING] 2026-07-27 23:54:05,545 [RapidOCR] provider_config.py:103: CUDAExecutionProvider is not in available providers (['AzureExecutionProvider', 'CPUExecutionProvider']). Use AzureExecutionProvider inference by default.
# [INFO] 2026-07-27 23:54:05,545 [RapidOCR] provider_config.py:203: If you want to use CUDAExecutionProvider acceleration, you must do:(For reference only) If you want to use GPU acceleration, you must do:
# [INFO] 2026-07-27 23:54:05,547 [RapidOCR] provider_config.py:203: First, uninstall all onnxruntime packages in current environment.
# [INFO] 2026-07-27 23:54:05,547 [RapidOCR] provider_config.py:203: Second, install onnxruntime-gpu by `pip install onnxruntime-gpu`.
# [INFO] 2026-07-27 23:54:05,548 [RapidOCR] provider_config.py:203: Note the onnxruntime-gpu version must match your cuda and cudnn version.
# [INFO] 2026-07-27 23:54:05,548 [RapidOCR] provider_config.py:203: You can refer this link: https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html
# [INFO] 2026-07-27 23:54:05,548 [RapidOCR] provider_config.py:203: Third, ensure CUDAExecutionProvider is in available providers list. e.g. ['CUDAExecutionProvider', 'CPUExecutionProvider']
# [WARNING] 2026-07-27 23:54:05,610 [RapidOCR] provider_config.py:103: CUDAExecutionProvider is not in available providers (['AzureExecutionProvider', 'CPUExecutionProvider']). Use AzureExecutionProvider inference by default.
# [INFO] 2026-07-27 23:54:05,611 [RapidOCR] provider_config.py:203: If you want to use CUDAExecutionProvider acceleration, you must do:(For reference only) If you want to use GPU acceleration, you must do:
# [INFO] 2026-07-27 23:54:05,611 [RapidOCR] provider_config.py:203: First, uninstall all onnxruntime packages in current environment.
# [INFO] 2026-07-27 23:54:05,611 [RapidOCR] provider_config.py:203: Second, install onnxruntime-gpu by `pip install onnxruntime-gpu`.
# [INFO] 2026-07-27 23:54:05,613 [RapidOCR] provider_config.py:203: Note the onnxruntime-gpu version must match your cuda and cudnn version.
# [INFO] 2026-07-27 23:54:05,613 [RapidOCR] provider_config.py:203: You can refer this link: https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html
# [INFO] 2026-07-27 23:54:05,613 [RapidOCR] provider_config.py:203: Third, ensure CUDAExecutionProvider is in available providers list. e.g. ['CUDAExecutionProvider', 'CPUExecutionProvider']
# [INFO] 2026-07-27 23:54:05,614 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-07-27 23:54:05,626 [RapidOCR] download_file.py:60: File exists and is valid: C:\Software\anaconda3\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_mobile.onnx
# [INFO] 2026-07-27 23:54:05,627 [RapidOCR] main.py:65: Using C:\Software\anaconda3\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_mobile.onnx
# [WARNING] 2026-07-27 23:54:05,628 [RapidOCR] provider_config.py:103: CUDAExecutionProvider is not in available providers (['AzureExecutionProvider', 'CPUExecutionProvider']). Use AzureExecutionProvider inference by default.
# [INFO] 2026-07-27 23:54:05,628 [RapidOCR] provider_config.py:203: If you want to use CUDAExecutionProvider acceleration, you must do:(For reference only) If you want to use GPU acceleration, you must do:
# [INFO] 2026-07-27 23:54:05,628 [RapidOCR] provider_config.py:203: First, uninstall all onnxruntime packages in current environment.
# [INFO] 2026-07-27 23:54:05,628 [RapidOCR] provider_config.py:203: Second, install onnxruntime-gpu by `pip install onnxruntime-gpu`.
# [INFO] 2026-07-27 23:54:05,629 [RapidOCR] provider_config.py:203: Note the onnxruntime-gpu version must match your cuda and cudnn version.
# [INFO] 2026-07-27 23:54:05,629 [RapidOCR] provider_config.py:203: You can refer this link: https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html
# [INFO] 2026-07-27 23:54:05,629 [RapidOCR] provider_config.py:203: Third, ensure CUDAExecutionProvider is in available providers list. e.g. ['CUDAExecutionProvider', 'CPUExecutionProvider']
# [WARNING] 2026-07-27 23:54:05,846 [RapidOCR] provider_config.py:103: CUDAExecutionProvider is not in available providers (['AzureExecutionProvider', 'CPUExecutionProvider']). Use AzureExecutionProvider inference by default.
# [INFO] 2026-07-27 23:54:05,847 [RapidOCR] provider_config.py:203: If you want to use CUDAExecutionProvider acceleration, you must do:(For reference only) If you want to use GPU acceleration, you must do:
# [INFO] 2026-07-27 23:54:05,847 [RapidOCR] provider_config.py:203: First, uninstall all onnxruntime packages in current environment.
# [INFO] 2026-07-27 23:54:05,848 [RapidOCR] provider_config.py:203: Second, install onnxruntime-gpu by `pip install onnxruntime-gpu`.
# [INFO] 2026-07-27 23:54:05,848 [RapidOCR] provider_config.py:203: Note the onnxruntime-gpu version must match your cuda and cudnn version.
# [INFO] 2026-07-27 23:54:05,848 [RapidOCR] provider_config.py:203: You can refer this link: https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html
# [INFO] 2026-07-27 23:54:05,848 [RapidOCR] provider_config.py:203: Third, ensure CUDAExecutionProvider is in available providers list. e.g. ['CUDAExecutionProvider', 'CPUExecutionProvider']
# [WARNING] 2026-07-27 23:54:15,134 [RapidOCR] main.py:132: The text detection result is empty
# [WARNING] 2026-07-27 23:54:15,787 [RapidOCR] main.py:132: The text detection result is empty
# [WARNING] 2026-07-27 23:54:44,655 [RapidOCR] main.py:132: The text detection result is empty
# [WARNING] 2026-07-27 23:55:00,209 [RapidOCR] main.py:132: The text detection result is empty
# [WARNING] 2026-07-27 23:55:04,091 [RapidOCR] main.py:132: The text detection result is empty
# [WARNING] 2026-07-27 23:55:20,793 [RapidOCR] main.py:132: The text detection result is empty
#          image     truth                          rapid_raw   rapidocr  \
# 0     img1.jpg   MCY6055                    ('MCY', '6055')    MCY6055
# 1    img10.jpg  SJS4878P  ('Sr', '4', '8', '76', '8', 'JL')  SR48768JL
# 2   img100.jpg   BHR6449                      ('6449', 'R')      6449R
# 3    img11.jpg    SMR54X               ('SMR5', '54', '4X')   SMR5544X
# 4    img12.jpg   WJJ2495                    ('WJJ', '2495')    WJJ2495
# ..         ...       ...                                ...        ...
# 95   img95.jpg   VCH3295                      ('VCH 3295',)    VCH3295
# 96   img96.jpg    PQQ922                     ('PQQ', '922')     PQQ922
# 97   img97.jpg   PQU6175                   ('PQU6', '6175')   PQU66175
# 98   img98.jpg   WEE6996                       ('WEE6996',)    WEE6996
# 99   img99.jpg    KFW698                        ('KFW698',)     KFW698
#
#     rapid_ok  rapid_sim  det_conf
# 0          1     1.0000  0.819638
# 1          0     0.5882  0.731283
# 2          0     0.6667  0.769302
# 3          0     0.8571  0.783089
# 4          1     1.0000  0.861307
# ..       ...        ...       ...
# 95         1     1.0000  0.889710
# 96         1     1.0000  0.770766
# 97         0     0.9333  0.841102
# 98         1     1.0000  0.859380
# 99         1     1.0000  0.837886
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Fourth cell: PaddleOCR

# %%
# PaddleOCR 3.x removed use_angle_cls / show_log / use_gpu from the
# constructor (show_log now hard-errors instead of warning, which is why
# init was failing). GPU/CPU is now picked with device='gpu'/'cpu', and the
# angle-classifier flag is now use_textline_orientation. We try the 3.x
# signature first and fall back to the legacy 2.x signature if that's what's
# actually installed.

paddle_engine = None
paddle_api = None  # 'v3' or 'v2', so the inference loop knows how to call it
if PaddleOCR is not None:
    device = 'gpu' if GPU_AVAILABLE else 'cpu'
    try:
        # PaddleOCR 3.x signature
        paddle_engine = PaddleOCR(use_textline_orientation=True, lang='en', device=device)
        paddle_api = 'v3'
    except TypeError as e:
        # TypeError here means the installed version doesn't recognize these
        # kwargs at all -- i.e. it's the older 2.x API instead.
        print(f'[paddleocr] v3-style init failed ({type(e).__name__}: {e}), trying legacy v2 API')
        try:
            paddle_engine = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=GPU_AVAILABLE)
            paddle_api = 'v2'
        except Exception as e2:
            print(f'[paddleocr legacy init also failed] {type(e2).__name__}: {e2}')
            paddle_engine = None
    except Exception as e:
        # GPU device requested but not actually usable -> retry on CPU.
        print(f'[paddleocr GPU init failed, retrying on CPU] {type(e).__name__}: {e}')
        try:
            paddle_engine = PaddleOCR(use_textline_orientation=True, lang='en', device='cpu')
            paddle_api = 'v3'
        except Exception as e2:
            print(f'[paddleocr CPU init also failed] {type(e2).__name__}: {e2}')
            paddle_engine = None
else:
    print('[paddleocr] not available -- see import error above')

paddle_rows = []
for p in img_paths:
    truth_row = gt.loc[gt['image'] == p.name, 'plate']
    truth = clean(truth_row.iloc[0]) if len(truth_row) else ''
    img_bgr = cv2.imread(str(p))
    crop, det_conf = detect_plate_crop(img_bgr)

    pred = ''
    paddle_raw = ''
    if paddle_engine is not None and crop is not None:
        try:
            texts = []
            if paddle_api == 'v3':
                # .predict() returns a list of result objects (dict-like),
                # one per input image; each has a 'rec_texts' list.
                results = paddle_engine.predict(crop)
                paddle_raw = str(results)
                if results:
                    res0 = results[0]
                    texts = res0.get('rec_texts', []) if hasattr(res0, 'get') else getattr(res0, 'rec_texts', [])
            else:
                # legacy .ocr() -> list of [box, (text, score)] per image
                result = paddle_engine.ocr(crop, cls=True)
                paddle_raw = str(result)
                if result and result[0]:
                    texts = [line[1][0] for line in result[0]]
            texts = texts or []
            pred = clean(''.join(texts))
        except Exception as e:
            paddle_raw = f'ERR: {type(e).__name__}: {e}'
            pred = ''
    elif paddle_engine is None:
        paddle_raw = 'ERR: paddleocr engine not initialized'
    elif crop is None:
        paddle_raw = 'ERR: no plate detected by YOLO'

    paddle_rows.append({
        'image': p.name,
        'truth': truth,
        'paddle_raw': paddle_raw,
        'paddleocr': pred,
        'paddle_ok': int(pred == truth),
        'paddle_sim': round(sim(pred, truth), 4),
        'det_conf': det_conf
    })

paddle_df = pd.DataFrame(paddle_rows)
paddle_df.to_csv(OUT_DIR / 'paddleocr_results.csv', index=False)
paddle_df
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\USER 1\.paddlex\official_models\PP-LCNet_x1_0_doc_ori`.
# The specified device (GPU) is not available! Switching to CPU instead.
# Creating model: ('UVDoc', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\USER 1\.paddlex\official_models\UVDoc`.
# The specified device (GPU) is not available! Switching to CPU instead.
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\USER 1\.paddlex\official_models\PP-LCNet_x1_0_textline_ori`.
# The specified device (GPU) is not available! Switching to CPU instead.
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\USER 1\.paddlex\official_models\PP-OCRv5_server_det`.
# The specified device (GPU) is not available! Switching to CPU instead.
# Creating model: ('en_PP-OCRv5_mobile_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\USER 1\.paddlex\official_models\en_PP-OCRv5_mobile_rec`.
# The specified device (GPU) is not available! Switching to CPU instead.
#          image     truth                                         paddle_raw  \
# 0     img1.jpg   MCY6055  [{'input_path': None, 'page_index': None, 'doc...
# 1    img10.jpg  SJS4878P  [{'input_path': None, 'page_index': None, 'doc...
# 2   img100.jpg   BHR6449  [{'input_path': None, 'page_index': None, 'doc...
# 3    img11.jpg    SMR54X  [{'input_path': None, 'page_index': None, 'doc...
# 4    img12.jpg   WJJ2495  [{'input_path': None, 'page_index': None, 'doc...
# ..         ...       ...                                                ...
# 95   img95.jpg   VCH3295  [{'input_path': None, 'page_index': None, 'doc...
# 96   img96.jpg    PQQ922  [{'input_path': None, 'page_index': None, 'doc...
# 97   img97.jpg   PQU6175  [{'input_path': None, 'page_index': None, 'doc...
# 98   img98.jpg   WEE6996  [{'input_path': None, 'page_index': None, 'doc...
# 99   img99.jpg    KFW698  [{'input_path': None, 'page_index': None, 'doc...
#
#    paddleocr  paddle_ok  paddle_sim  det_conf
# 0    MCY6055          1      1.0000  0.819638
# 1   SJS4878P          1      1.0000  0.731283
# 2    BHE6440          0      0.7143  0.769302
# 3     SMR54X          1      1.0000  0.783089
# 4    2495TCM          0      0.5714  0.861307
# ..       ...        ...         ...       ...
# 95   VCH3295          1      1.0000  0.889710
# 96    O06022          0      0.3333  0.770766
# 97   PQU6175          1      1.0000  0.841102
# 98   WEE6996          1      1.0000  0.859380
# 99    KFW698          1      1.0000  0.837886
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Combined comparison table

# %%
combined = pd.DataFrame({'image': gt['image'].astype(str), 'truth': gt['plate'].astype(str)})
combined = combined.merge(fast_df[['image','fast_plate_ocr','fast_ok','fast_sim']], on='image', how='left')
combined = combined.merge(easy_df[['image','easyocr','easy_ok','easy_sim']], on='image', how='left')
combined = combined.merge(rapid_df[['image','rapidocr','rapid_ok','rapid_sim']], on='image', how='left')
combined = combined.merge(paddle_df[['image','paddleocr','paddle_ok','paddle_sim']], on='image', how='left')
combined.to_csv(OUT_DIR / 'ocr_combined_comparison.csv', index=False)

summary = pd.DataFrame({
    'OCR': ['fast_plate_ocr', 'easyocr', 'rapidocr', 'paddleocr'],
    'ExactMatchAcc': [combined['fast_ok'].mean(), combined['easy_ok'].mean(), combined['rapid_ok'].mean(), combined['paddle_ok'].mean()],
    'AvgSim': [combined['fast_sim'].mean(), combined['easy_sim'].mean(), combined['rapid_sim'].mean(), combined['paddle_sim'].mean()]
})
summary.to_csv(OUT_DIR / 'ocr_summary.csv', index=False)
combined
# Out:
#          image      truth fast_plate_ocr  fast_ok  fast_sim    easyocr  \
# 0     img1.jpg    MCY6055        MCY6055        1       1.0    MCY6055
# 1     img2.jpg    WHN9050        WHN9050        1       1.0    WHN9050
# 2     img3.jpg      WRA73          WRA73        1       1.0      MRA73
# 3     img4.jpg    NEG8531        NEG8531        1       1.0    NEG8531
# 4     img5.jpg  B87777NRS      B87777NRS        1       1.0  B87777NRS
# ..         ...        ...            ...      ...       ...        ...
# 95   img96.jpg     PQQ922         PQQ922        1       1.0     PQQ922
# 96   img97.jpg    PQU6175        PQU6175        1       1.0    POU6175
# 97   img98.jpg    WEE6996        WEE6996        1       1.0    WEE6996
# 98   img99.jpg     KFW698         KFW698        1       1.0     KFW69B
# 99  img100.jpg    BHR6449        BHR6449        1       1.0    BHR6449
#
#     easy_ok  easy_sim    rapidocr  rapid_ok  rapid_sim  paddleocr  paddle_ok  \
# 0         1    1.0000     MCY6055         1     1.0000    MCY6055          1
# 1         1    1.0000     WHN9050         1     1.0000    9050NHM          0
# 2         0    0.8000      WRA473         0     0.9091      WRA73          1
# 3         1    1.0000     NEG8531         1     1.0000   G8531NEG          0
# 4         1    1.0000  B887777NRS         0     0.9474  B87777NRS          1
# ..      ...       ...         ...       ...        ...        ...        ...
# 95        1    1.0000      PQQ922         1     1.0000     O06022          0
# 96        0    0.8571    PQU66175         0     0.9333    PQU6175          1
# 97        1    1.0000     WEE6996         1     1.0000    WEE6996          1
# 98        0    0.8333      KFW698         1     1.0000     KFW698          1
# 99        1    1.0000       6449R         0     0.6667    BHE6440          0
#
#     paddle_sim
# 0       1.0000
# 1       0.5714
# 2       1.0000
# 3       0.6667
# 4       1.0000
# ..         ...
# 95      0.3333
# 96      1.0000
# 97      1.0000
# 98      1.0000
# 99      0.7143
#
# [100 rows x 14 columns]

# %% [markdown]
# ## Summary table

# %%
summary
